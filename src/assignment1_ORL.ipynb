# %% [markdown]
# ## COMP5328 - Advanced Machine Learning
# ## Assignment 1: Non-negative Matrix Factorization
# ----------------------------------------------------------------------------------------

# %% [markdown]
# **(Semester 2, 2020)**
#
# In this ipython notebook, we provide some example code for assignment1.
# + Load Data.
#     - ORL dataset.
#     - Extended YaleB dataset.
#     - AR dataset (**optional**).
# + Perform Evaluation.
#    - Relative Reconstruction Errors.
#    - Accuracy, NMI (**optional**).
#
# Lecturer: Tongliang Liu.
#
# Tutors: Nicholas James, Songhua Wu, Xuefeng Li, Yu Yao.
#
# **Note: All datasets can be used only for this assignment and you are not allowed to distribute these datasets. If you want to use AR dataset, you need to apply it by yourself (we do not provide AR dataset due to the problem of license, please find more details in http://www2.ece.ohio-state.edu/~aleix/ARdatabase.html).**

# %% [markdown]
# ## 0. Load Modules

# %%
# autoreload for modules
# %load_ext autoreload
# %autoreload 2

# Define your functions in organised individual python files. Don't throw them randomly in the notebook

## Import image processing modules
import os
import numpy as np
import pandas as pd # Used for simpler processing of data
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt

from utils import *

## Import Algorithms
from algs import NmfHyperEstimator, NmfL2Estimator, ModifiedNMF

#Import preprocessing
from preprocessing import SaltNPepper, Gaussian, ImageNormalizer
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Load Dataset
#
# ### 1.0 Data Folder

# %%
# The structure of data folder.
# !ls -l data
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %% [raw]
# # Tree structure of data folder.
# ├── CroppedAR
#     ├── M-001-01.bmp
#     ├── M-001-01.txt
#     ├── M-001-02.bmp
#     ├── M-001-02.txt
#     ├── ...
# ├── CroppedYaleB
# │   ├── yaleB01
# │   ├── yaleB02
# │   ...
# │   ├── yaleB38
# │   └── yaleB39
# └── ORL
#     ├── s1
#     ├── s2
#     ├── s3
#     ├── ...
#     ├── s40

# %% [markdown]
# ### 1.1 Load ORL Dataset and Extended YaleB Dataset.
# + ORL dataset contains ten different images of each of 40 distinct subjects. For some subjects, the images were taken at different times, varying the lighting, facial expressions (open / closed eyes, smiling / not smiling) and facial details (glasses / no glasses). All the images were taken against a dark homogeneous background with the subjects in an upright, frontal position (with tolerance for some side movement). The size of each image is 92x112 pixels, with 256 grey levels per pixel. To further reduce the computation complexity, you can resize all images to 30x37 pixels.
#
# + Extended YaleB dataset contains 2414 images of 38 human subjects under 9 poses and 64 illumination conditions. All images are manually aligned, cropped, and then resized to 168x192 pixels. To further reduce the computation complexity, you can resize all images to 42x48 pixels.

# %%
# Load ORL dataset.
X_orl, Y_orl = load_data(root='data/ORL', reduce=2)
print('ORL dataset: X.shape = {}, Y.shape = {}'.format(X_orl.shape, Y_orl.shape))
# Out:
# ORL dataset: X.shape = (2576, 400), Y.shape = (400,)

# %% [markdown]
# ## 2. Evaluation Metrics
#
#
# ### 2.1 Relative Reconstruction Errors (RRE)
#
# To compare the robustness of different NMF algorithms, you can use the ```relative reconstruction errors```. Let $V$ denote the contaminated dataset (by adding noise), and $\hat{V}$
#  denote the clean dataset. Let $W$ and $H$ denote the factorization results on $V$, the ``relative reconstruction errors`` then can be defined as follows:
#  \begin{equation}
#     RRE = \frac{ \| \hat{V} - WH \|_F }{ \| \hat{V} \|_F}.
# \end{equation}

# %% [markdown]
# ### With scaling the data

# %%
#Demonstrate noisy Image
V_hat, Y_hat = load_data(root='data/ORL', reduce=3)
scaler = ImageNormalizer(min=0,max=1)

noise = SaltNPepper(p=0.1, r=0.4) 

V_snp = noise.fit_transform(V_hat)
V_snp = scaler.fit_transform(V_snp)

noise_g = Gaussian(mean=0, sigma=10) 
V_g = noise_g.fit_transform(V_hat)
V_g = scaler.fit_transform(V_g)

# %%
#Plot result.
img_size = [i//3 for i in (90, 111)] #ORL
ind = 2 # index of demo image.
plt.figure(figsize=(12,3))
plt.subplot(131)
plt.imshow(V_hat[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image(Original)')
plt.subplot(132)
plt.imshow(V_snp[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image(snp Noise) p=0.1 r=0.4')
plt.subplot(133)
plt.imshow(V_g[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image(Gaussian noise) mean=0 sd=10')
plt.draw()
plt.savefig("noisyImage", dpi=100)
plt.show()

# %%
#Image Reconstruction
#Using Hypersurface
np.random.seed(0)
nmf_hyper = NmfHyperEstimator(n_components=50) # set n_components to num_classes.
#Salt n Pepper
H = nmf_hyper.fit_transform(V_snp)
W = nmf_hyper.components_
V_snp_reconstructed_hyper = W @ H
#Gaussian
H = nmf_hyper.fit_transform(V_g)
V_g_reconstructed_hyper = W @ H

#Using L2NMF
np.random.seed(0)
nmf_L2 = NmfL2Estimator(n_components=50) # set n_components to num_classes.
#SaltNPepper
H = nmf_L2.fit_transform(V_snp)
W = nmf_L2.components_
V_snp_reconstructed_L2 = W @ H
#Gaussian
H = nmf_L2.fit_transform(V_g)
V_g_reconstructed_L2 = W @ H

# %%
#Reconstruction (snp noise) using hyper
img_size = [i//3 for i in (90, 111)] #ORL
ind = 2 # index of demo image.
plt.figure(figsize=(12,3))
plt.subplot(131)
plt.imshow(V_hat[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Original)')
plt.subplot(132)
plt.imshow(V_snp[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (snp Noise) p=0.1 r=0.4')
plt.subplot(133)
plt.imshow(V_snp_reconstructed_hyper[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Reconstructed)')
plt.savefig("reconstructedHyper_snp.png", dpi=100)

# %%
#Reconstruction (Gaussian noise) using hyper
img_size = [i//3 for i in (90, 111)] #ORL
ind = 2 # index of demo image.
plt.figure(figsize=(12,3))
plt.subplot(131)
plt.imshow(V_hat[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Original)')
plt.subplot(132)
plt.imshow(V_g[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Gaussian noise) mean=20, sd=10')
plt.subplot(133)
plt.imshow(V_g_reconstructed_hyper[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Reconstructed)')
plt.savefig("reconstructedHyper_gaussian", dpi=100)

# %%
#Reconstruction (snp noise) using L2NMF
img_size = [i//3 for i in (90, 111)] #ORL
ind = 2 # index of demo image.
plt.figure(figsize=(12, 3))
plt.subplot(131)
plt.imshow(V_hat[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Original)')
plt.subplot(132)
plt.imshow(V_snp[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (snp Noise) p=0.1 r=0.4')
plt.subplot(133)
plt.imshow(V_snp_reconstructed_L2[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Reconstructed)')
plt.savefig("reconstructedL2_snp", dpi=100)

# %%
#Reconstruction (Gaussian noise) using L2NMF
img_size = [i//3 for i in (90, 111)] #ORL
ind = 2 # index of demo image.
plt.figure(figsize=(12, 3))
plt.subplot(131)
plt.imshow(V_hat[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Original)')
plt.subplot(132)
plt.imshow(V_g[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image(Gaussian noise) mean=20, sd=10')
plt.subplot(133)
plt.imshow(V_g_reconstructed_L2[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Reconstructed)')
plt.savefig("reconstructedL2_gaussian", dpi=100)

# %% [markdown]
# ### Without scaling the data

# %%
V_hat, Y_hat = load_data(root='data/ORL', reduce=3)
scaler = ImageNormalizer(min=None,max=None)

noise = SaltNPepper(p=0.1, r=0.4) 
noise_g = Gaussian(mean=0, sigma=10)

V_snp = noise.fit_transform(V_hat)
V_snp = scaler.fit_transform(V_snp)

V_g = noise_g.fit_transform(V_hat)
V_g = scaler.fit_transform(V_g)

# %%
#Plot result.
img_size = [i//3 for i in (90, 111)] #ORL
ind = 2 # index of demo image.
plt.figure(figsize=(12,3))
plt.subplot(131)
plt.imshow(V_hat[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image(Original)')
plt.subplot(132)
plt.imshow(V_snp[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image(snp Noise) p=0.1 r=0.4')
plt.subplot(133)
plt.imshow(V_g[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image(Gaussian noise) mean=0 sd=10')
plt.draw()
plt.savefig("noisyImage", dpi=100)
plt.show()

# %%
#Using Hypersurface
np.random.seed(0)
nmf_hyper = NmfHyperEstimator(n_components=50) # set n_components to num_classes.
#Salt n Pepper
H = nmf_hyper.fit_transform(V_snp)
W = nmf_hyper.components_
V_snp_reconstructed_hyper = W @ H
#Gaussian
H = nmf_hyper.fit_transform(V_g)
V_g_reconstructed_hyper = W @ H

#Using L2NMF
np.random.seed(0)
nmf_L2 = NmfL2Estimator(n_components=50) # set n_components to num_classes.
#SaltNPepper
H = nmf_L2.fit_transform(V_snp)
W = nmf_L2.components_
V_snp_reconstructed_L2 = W @ H
#Gaussian
H = nmf_L2.fit_transform(V_g)
V_g_reconstructed_L2 = W @ H

# %%
#Reconstruction (snp noise) using hyper
img_size = [i//3 for i in (90, 111)] #ORL
ind = 2 # index of demo image.
plt.figure(figsize=(12,3))
plt.subplot(131)
plt.imshow(V_hat[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Original)')
plt.subplot(132)
plt.imshow(V_snp[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (snp Noise) p=0.1 r=0.4')
plt.subplot(133)
plt.imshow(V_snp_reconstructed_hyper[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Reconstructed)')
plt.savefig("reconstructedHyper_snp.png", dpi=100)

# %%
#Reconstruction (Gaussian noise) using hyper
img_size = [i//3 for i in (90, 111)] #ORL
ind = 2 # index of demo image.
plt.figure(figsize=(12,3))
plt.subplot(131)
plt.imshow(V_hat[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Original)')
plt.subplot(132)
plt.imshow(V_g[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Gaussian noise) mean=20, sd=10')
plt.subplot(133)
plt.imshow(V_g_reconstructed_hyper[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Reconstructed)')
plt.savefig("reconstructedHyper_gaussian", dpi=100)

# %%
#Reconstruction (snp noise) using L2NMF
img_size = [i//3 for i in (90, 111)] #ORL
ind = 2 # index of demo image.
plt.figure(figsize=(12, 3))
plt.subplot(131)
plt.imshow(V_hat[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Original)')
plt.subplot(132)
plt.imshow(V_snp[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (snp Noise) p=0.1 r=0.4')
plt.subplot(133)
plt.imshow(V_snp_reconstructed_L2[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Reconstructed)')
plt.savefig("reconstructedL2_snp", dpi=100)

# %%
#Reconstruction (Gaussian noise) using L2NMF
img_size = [i//3 for i in (90, 111)] #ORL
ind = 2 # index of demo image.
plt.figure(figsize=(12, 3))
plt.subplot(131)
plt.imshow(V_hat[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Original)')
plt.subplot(132)
plt.imshow(V_g[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image(Gaussian noise) mean=20, sd=10')
plt.subplot(133)
plt.imshow(V_g_reconstructed_L2[:,ind].reshape(img_size[1],img_size[0]), cmap=plt.cm.gray)
plt.title('Image (Reconstructed)')
plt.savefig("reconstructedL2_gaussian", dpi=100)

# %% [markdown]
# ### 2.2 Evaluate Clustering Performance
#
# 1. Accuracy.
#
#     $$ Acc(Y, Y_{pred}) = \frac{1}{n}\sum\limits_{i=1}^n 1\{Y_{pred}(i) == Y(i)\}$$
#
# 2. Normalized Mutual Information (NMI).
#
#     $$ NMI(Y, Y_{pred}) = \frac{2 * I(Y, Y_{pred})}{H(Y) + H(Y_{pred})} $$
#
#    where $ I(\cdot,\cdot) $ is mutual information and $ H(\cdot) $ is entropy.

# %%
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.metrics import normalized_mutual_info_score

def assign_cluster_label(X, Y):
    kmeans = KMeans(n_clusters=len(set(Y))).fit(X)
    Y_pred = np.zeros(Y.shape)
    for i in set(kmeans.labels_):
        ind = kmeans.labels_ == i
        Y_pred[ind] = Counter(Y[ind]).most_common(1)[0][0] # assign label.
    return Y_pred

# %% [markdown]
# ## Performance comparison (with scaling) with 40% samples

# %%
X, Y, scaler = X_orl, Y_orl, ImageNormalizer(min=0,max=1)
alg_kwargs_pairs = [
    ModifiedNMF, 
    NmfL2Estimator,
    NmfHyperEstimator#, {"max_armijo": 2, "alpha0": 0.3, "beta0": 0.5, "init": 'random'}] # disable armijo search
]

metrics = [rre_score, acc_score, nmi_score]
metrics_names = ["rre", "acc_score", "nmi_score"]
n_trials = 3         #No of random samples considered for training
pc_sample = 0.4      #Training with 40% data

# %%
#Saltnpepper noise
all_n_components = range(30, 60, 20)
noise_alg = SaltNPepper
noise_levels = np.arange(0, 0.5, 0.1)
ratios = [0.5] #np.arange(0.0, 1, 0.5)
noise_kwargs_pairs = make_grid_alg_kwargs(noise_alg, p=noise_levels, r=ratios)

evaluations = benchmark(X_orl, Y_orl, scaler,
                        alg_kwargs_pairs, all_n_components,
                        noise_kwargs_pairs,
                        metrics, metrics_names,
                        n_trials, pc_sample
                       )
# Out:
# Noise: {'noise_id': 0, 'p': 0.0, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 1, 'p': 0.1, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 2, 'p': 0.2, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 3, 'p': 0.30000000000000004, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 4, 'p': 0.4, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}

# %%
# Plotting RRE, Accuracy and NMI scores against different Salt & pepper noise levels for n_components=50
fig = plt.figure(figsize=[9, 12])

ax = fig.add_subplot(311)
sns.lineplot(
    x="p",
    y="rre",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations.query("n_components == 50"),
    estimator='mean',
    ci=95,
    n_boot=1000,
    seed=None,
    sort=True,
    err_style='band',
    #legend='full',
)
ax.set_xlabel('')
ax.set_ylabel("Relative Reconstruction Error")
ax.legend(title="Algorithm", loc="upper left", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])

ax = fig.add_subplot(312)
sns.lineplot(
    x="p",
    y="acc_score",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations.query("n_components == 50"),# and alg == 'NmfHyperEstimator'"),
    estimator='mean',
    ci=95,
    n_boot=1000,
    seed=None,
    sort=True,
    err_style='band',
    legend='full',
)
ax.set_xlabel('')
ax.set_ylabel("Accuracy Score")
ax.legend(title="Algorithm", loc="upper right", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])

ax = fig.add_subplot(313)
sns.lineplot(
    x="p",
    y="nmi_score",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations.query("n_components == 50"),# and noise_level==0.1"),# and alg == 'NmfHyperEstimator'"),
    estimator='mean',
    ci=95,
    markers=True,
    n_boot=1000,
    seed=None,
    sort=True,
    err_style='band',
    legend='full',
)
ax.set_xlabel("Noise level")
ax.set_ylabel("Normalised Mutual Info Score")
ax.legend(title="Algorithm", loc="upper right", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])
plt.title("Model performances with n_components=50")
plt.savefig("snp_scaled_40%")

# %%
# Measuring RRE, Accuracy and NMI scores vs salt and pepper ratio for n_components=30 and noise at 0.1
fig = plt.figure(figsize=[9, 12])

ax = fig.add_subplot(311)
sns.lineplot(
    x="ratio",
    y="rre",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations.query("n_components == 50 and noise_level==0.1"),# and alg == 'NmfHyperEstimator'"),
    estimator='mean',
    #ci=95,
    ci = 'sd',
    markers=True,
    n_boot=1000,
    seed=None,
    sort=True,
    err_style='band',
    legend='full',
)
ax.set_xlabel('')
ax.set_ylabel("Relative Reconstruction Error")
ax.legend(title="Algorithm", loc="upper left", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])

ax = fig.add_subplot(312)
sns.lineplot(
    x="ratio",
    y="acc_score",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations.query("n_components == 50 and noise_level==0.1"),
    estimator='mean',
    #ci=95,
    ci = 'sd',
    markers=True,
    n_boot=1000,
    seed=None,
    sort=True,
    err_style='band',
    legend='full',
)
ax.set_xlabel('')
ax.set_ylabel("Accuracy Score")
ax.legend(title="Algorithm", loc="upper left", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])

ax = fig.add_subplot(313)
sns.lineplot(
    x="ratio",
    y="nmi_score",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations.query("n_components == 50 and noise_level==0.1"),# and alg == 'NmfHyperEstimator'"),
    estimator='mean',
    #ci=95,
    ci = 'sd',
    markers=True,
    n_boot=1000,
    seed=None,
    sort=True,
    err_style='band'
)
ax.set_xlabel("Ratio of salt and pepper (0 for all salt, 1 for all pepper)")
ax.set_ylabel("Normalised Mutual Info Score")
ax.legend(title="Algorithm", loc="upper left", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])
plt.savefig("fig2")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# G:\Python\Anaconda\lib\collections\__init__.py in __getitem__(self, key)
#     897                 pass
# --> 898         return self.__missing__(key)            # support subclasses that define __missing__
#     899
#
# G:\Python\Anaconda\lib\collections\__init__.py in __missing__(self, key)
#     889     def __missing__(self, key):
# --> 890         raise KeyError(key)
#     891
#
# KeyError: 'noise_level'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     197                 # e.g., df[df > 0]
# --> 198                 return self.temps[key]
#     199             except KeyError:
#
# KeyError: 'noise_level'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-110-f30ac8ada0da> in <module>
#       9     #size="n_components",
#      10     style="alg",
# ---> 11     data=evaluations.query("n_components == 50 and noise_level==0.1"),# and alg == 'NmfHyperEstimator'"),
#      12     estimator='mean',
#      13     #ci=95,
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     330         )
#     331
# --> 332         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     333
#     334         # construct the engine and evaluate the parsed expression
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in __init__(self, expr, engine, parser, env, level)
#     762         self.parser = parser
#     763         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 764         self.terms = self.parse()
#     765
#     766     @property
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in parse(self)
#     779     def parse(self):
#     780         """Parse an expression"""
# --> 781         return self._visitor.visit(self.expr)
#     782
#     783     @property
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit_Module(self, node, **kwargs)
#     379             raise SyntaxError("only a single expression is allowed")
#     380         expr = node.body[0]
# --> 381         return self.visit(expr, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit_Expr(self, node, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
# --> 384         return self.visit(node.value, **kwargs)
#     385
#     386     def _rewrite_membership_op(self, node, left, right):
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit_BoolOp(self, node, **kwargs)
#     701
#     702         operands = node.values
# --> 703         return reduce(visitor, operands)
#     704
#     705
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visitor(x, y)
#     695         def visitor(x, y):
#     696             lhs = self._try_visit_binop(x)
# --> 697             rhs = self._try_visit_binop(y)
#     698
#     699             op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in _try_visit_binop(self, bop)
#     690         if isinstance(bop, (Op, Term)):
#     691             return bop
# --> 692         return self.visit(bop)
#     693
#     694     def visit_BoolOp(self, node, **kwargs):
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit_Compare(self, node, **kwargs)
#     674             op = self.translate_In(ops[0])
#     675             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 676             return self.visit(binop)
#     677
#     678         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit_BinOp(self, node, **kwargs)
#     495
#     496     def visit_BinOp(self, node, **kwargs):
# --> 497         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     498         left, right = self._maybe_downcast_constants(left, right)
#     499         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     414     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     415         if left is None:
# --> 416             left = self.visit(node.left, side="left")
#     417         if right is None:
#     418             right = self.visit(node.right, side="right")
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\expr.py in visit_Name(self, node, **kwargs)
#     508
#     509     def visit_Name(self, node, **kwargs):
# --> 510         return self.term_type(node.id, self.env, **kwargs)
#     511
#     512     def visit_NameConstant(self, node, **kwargs):
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\ops.py in __init__(self, name, env, side, encoding)
#      80         tname = str(name)
#      81         self.is_local = tname.startswith(_LOCAL_TAG) or tname in _DEFAULT_GLOBALS
# ---> 82         self._value = self._resolve_name()
#      83         self.encoding = encoding
#      84
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\ops.py in _resolve_name(self)
#      97
#      98     def _resolve_name(self):
# ---> 99         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     100         self.update(res)
#     101
#
# G:\Python\Anaconda\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     201                 from pandas.core.computation.ops import UndefinedVariableError
#     202
# --> 203                 raise UndefinedVariableError(key, is_local)
#     204
#     205     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'noise_level' is not defined

# %%
# Gaussian noise
noise_alg = Gaussian
means = [0]
sigmas = list(range(0, 25, 5))
noise_kwargs_pairs = make_grid_alg_kwargs(noise_alg, mean=means, sigma=sigmas)

evaluations_g = benchmark(X_orl, Y_orl, scaler,
                        alg_kwargs_pairs, all_n_components,
                        noise_kwargs_pairs,
                        metrics, metrics_names,
                        n_trials, pc_sample
                       )
# Out:
# Noise: {'noise_id': 0, 'mean': 0, 'sigma': 0}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 1, 'mean': 0, 'sigma': 5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-acaa8f8c9558> in <module>
#       5 noise_kwargs_pairs = make_grid_alg_kwargs(noise_alg, mean=means, sigma=sigmas)
#       6
# ----> 7 evaluations_g = benchmark(X_orl, Y_orl, scaler,
#       8                         alg_kwargs_pairs, all_n_components,
#       9                         noise_kwargs_pairs,
#
# ~\comp5328\utils\evaluation.py in benchmark(X, Y, scaler, alg_kwargs_pairs, all_n_components, noise_kwargs_pairs, metrics, metrics_names, n_trials, pc_sample)
#     103                         {"alg": alg.__name__, "n_components": k, "kwargs": alg_kwargs, "trial_id": i})
#     104                     model = alg(n_components=k, **alg_kwargs)
# --> 105                     H = model.fit_transform(X_subset)
#     106                     W = model.components_
#     107                     # print(model.__class__, "W", W.shape, "H", H.shape)
#
# ~\comp5328\algs\sknmf_benchmark.py in fit_transform(self, X, *args, **kwargs)
#      18     def fit_transform(self, X, *args, **kwargs):
#      19         X = X.T
# ---> 20         return self.nmf.fit_transform(X, *args, **kwargs).T
#      21
#      22     @property
#
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py in fit_transform(self, X, y, W, H)
#    1281                                 dtype=[np.float64, np.float32])
#    1282
# -> 1283         W, H, n_iter_ = non_negative_factorization(
#    1284             X=X, W=W, H=H, n_components=self.n_components, init=self.init,
#    1285             update_H=True, solver=self.solver, beta_loss=self.beta_loss,
#
# G:\Python\Anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py in non_negative_factorization(X, W, H, n_components, init, update_H, solver, beta_loss, tol, max_iter, alpha, l1_ratio, regularization, random_state, verbose, shuffle)
#    1008     X = check_array(X, accept_sparse=('csr', 'csc'),
#    1009                     dtype=[np.float64, np.float32])
# -> 1010     check_non_negative(X, "NMF (input X)")
#    1011     beta_loss = _check_string_param(solver, regularization, beta_loss, init)
#    1012
#
# G:\Python\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_non_negative(X, whom)
#    1045
#    1046     if X_min < 0:
# -> 1047         raise ValueError("Negative values in data passed to %s" % whom)
#    1048
#    1049
#
# ValueError: Negative values in data passed to NMF (input X)

# %%
(evaluations_g.query("alg == 'NmfHyperEstimator' and n_components == 100")# and ratio==0.5")
 .sort_values(["rre"]))#, "acc_score"]))
# Out:
# Empty DataFrame
# Columns: [alg, n_components, kwargs, noise_id, noise_level, ratio, trial_id, rre, acc_score, nmi_score, mean, sigma]
# Index: []

# %%
type(evaluations_g)
# Out:
# pandas.core.frame.DataFrame

# %%
# Plotting RRE, Accuracy and NMI scores against different Gaussian noise levels for n_components=50
fig = plt.figure(figsize=[9, 12])

ax = fig.add_subplot(311)
sns.lineplot(
    x="sigma",
    y="rre",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations_g.query("n_components == 50"),# and noise_level==0.1"),# and alg == 'NmfHyperEstimator'"),
    estimator='mean',
    #ci=95,
    ci = 'sd',
    n_boot=1000,
    seed=None,
    markers=True,
    sort=True,
    err_style='band',
    legend=False,
)
ax.set_xlabel('')
#ax.legend(title="Algorithm", loc="bottom right", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])
ax.set_ylabel("Relative Reconstruction Error")

ax = fig.add_subplot(312)
sns.lineplot(
    x="sigma",
    y="acc_score",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations_g.query("n_components == 50"),# and alg == 'NmfHyperEstimator'"),
    estimator='mean',
    #ci=95,
    ci = 'sd',
    markers=True,
    n_boot=1000,
    seed=None,
    sort=True,
    err_style='band',
    legend='full',
)
ax.set_xlabel('')
ax.set_ylabel("Accuracy Score")
#ax.legend(title="Algorithm", loc="upper right", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])

ax = fig.add_subplot(313)
sns.lineplot(
    x="sigma",
    y="nmi_score",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations_g.query("n_components == 50"),# and noise_level==0.1"),# and alg == 'NmfHyperEstimator'"),
    estimator='mean',
    #ci=95,
    ci = 'sd',
    markers=True,
    n_boot=1000,
    seed=None,
    sort=True,
    err_style='band',
    legend='full',
)
ax.set_xlabel("Noise level (sigma)")
ax.set_ylabel("Normalised Mutual Info Score")
ax.legend(title="Algorithm", loc="upper right", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])
plt.savefig("Gaussian_ORL_normalised_40%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-62286d274567> in <module>
#       9     #size="n_components",
#      10     style="alg",
# ---> 11     data=evaluations_g.query("n_components == 50"),# and noise_level==0.1"),# and alg == 'NmfHyperEstimator'"),
#      12     estimator='mean',
#      13     #ci=95,
#
# NameError: name 'evaluations_g' is not defined

# %%
DataFrame.to_latex

# %% [markdown]
# ## Performance comparison (without scaling) with 40% samples

# %%
X, Y, scaler = X_orl, Y_orl, ImageNormalizer(min=None,max=None)
alg_kwargs_pairs = [
    ModifiedNMF, 
    NmfL2Estimator,
    NmfHyperEstimator
]

metrics = [rre_score, acc_score, nmi_score]
metrics_names = ["rre", "acc_score", "nmi_score"]
n_trials = 3         #No of random samples considered for training
pc_sample = 0.4      #Training with 40% data

# %%
#Saltnpepper noise
all_n_components = [range(30, 60, 20)]
noise_alg = SaltNPepper
noise_levels = np.arange(0, 0.5, 0.1)
ratios = [0.5] #np.arange(0.0, 1, 0.5)
noise_kwargs_pairs = make_grid_alg_kwargs(noise_alg, p=noise_levels, r=ratios)

evaluations_noScale = benchmark(X_orl, Y_orl, scaler,
                        alg_kwargs_pairs, all_n_components,
                        noise_kwargs_pairs,
                        metrics, metrics_names,
                        n_trials, pc_sample
                       )
# Out:
# Noise: {'noise_id': 0, 'p': 0.0, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 1, 'p': 0.1, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 2, 'p': 0.2, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 3, 'p': 0.30000000000000004, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 4, 'p': 0.4, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}

# %%
# Simple check for scores
(evaluations_noScale.query("alg == 'NmfHyperEstimator' and n_components == 30 and r==0.5")
 .sort_values(["rre"]))#, "acc_score"]))

evaluations.query("n_components==30 and ratio==0.5")
# Out:
# Empty DataFrame
# Columns: [alg, n_components, kwargs, noise_id, noise_level, ratio, trial_id, rre, acc_score, nmi_score, p, r]
# Index: []

# %%
# Plotting RRE, Accuracy and NMI scores against different Salt & pepper noise levels for n_components=50
fig = plt.figure(figsize=[9, 12])

ax = fig.add_subplot(311)
sns.lineplot(
    x="p",
    y="rre",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations_noScale.query("n_components == 50"),
    estimator='mean',
    ci=95,
    n_boot=1000,
    markers=True,
    seed=None,
    sort=True,
    err_style='band',
    #legend='full',
)
ax.set_xlabel('')
ax.set_ylabel("Relative Reconstruction Error")
ax.legend(title="Algorithm", loc="upper left", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])

ax = fig.add_subplot(312)
sns.lineplot(
    x="p",
    y="acc_score",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations_noScale.query("n_components == 50"),
    estimator='mean',
    ci=95,
    n_boot=1000,
    markers=True,
    seed=None,
    sort=True,
    err_style='band',
    legend='full',
)
ax.set_xlabel('')
ax.set_ylabel("Accuracy Score")
ax.legend(title="Algorithm", loc="upper right", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])

ax = fig.add_subplot(313)
sns.lineplot(
    x="p",
    y="nmi_score",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations_noScale.query("n_components == 50"),
    estimator='mean',
    ci=95,
    markers=True,
    n_boot=1000,
    seed=None,
    sort=True,
    err_style='band',
    legend='full',
)
ax.set_xlabel("Noise level")
ax.set_ylabel("Normalised Mutual Info Score")
ax.legend(title="Algorithm", loc="upper right", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])
plt.title("Model performances with n_components=50")
plt.savefig("snp_noScale_40%")

# %% [markdown]
# ## Performance comparison (with scaling) with 90% samples

# %%
X, Y, scaler = X_orl, Y_orl, ImageNormalizer(min=0,max=1)
alg_kwargs_pairs = [
    ModifiedNMF, 
    NmfL2Estimator,
    NmfHyperEstimator
]

metrics = [rre_score, acc_score, nmi_score]
metrics_names = ["rre", "acc_score", "nmi_score"]
n_trials = 3         #No of random samples considered for training
pc_sample = 0.9      #Training with 90% data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-6d0c7eeb418e> in <module>
#       3     ModifiedNMF,
#       4     NmfL2Estimator,
# ----> 5     NmfHyperEstimato
#       6 ]
#       7
#
# NameError: name 'NmfHyperEstimato' is not defined

# %%
#Saltnpepper noise
all_n_components = [50]
noise_alg = SaltNPepper
noise_levels = np.arange(0, 0.5, 0.1)
ratios = [0.5] #np.arange(0.0, 1, 0.5)
noise_kwargs_pairs = make_grid_alg_kwargs(noise_alg, p=noise_levels, r=ratios)

evaluations_90_snp = benchmark(X_orl, Y_orl, scaler,
                        alg_kwargs_pairs, all_n_components,
                        noise_kwargs_pairs,
                        metrics, metrics_names,
                        n_trials, pc_sample
                       )
# Out:
# Noise: {'noise_id': 0, 'p': 0.0, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 1, 'p': 0.1, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 2, 'p': 0.2, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 3, 'p': 0.30000000000000004, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
# Noise: {'noise_id': 4, 'p': 0.4, 'r': 0.5}
#     Trail: 0
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 1
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}
#     Trail: 2
#         Alg: ModifiedNMF {}
# G:\Python\Anaconda\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
#         Alg: NmfL2Estimator {}
#         Alg: NmfHyperEstimator {}

# %%
# Plotting RRE, Accuracy and NMI scores against different Salt & pepper noise levels for n_components=50
fig = plt.figure(figsize=[9, 12])

ax = fig.add_subplot(311)
sns.lineplot(
    x="p",
    y="rre",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations_90_snp.query("n_components == 50"),
    estimator='mean',
    ci=95,
    n_boot=1000,
    markers=True,
    seed=None,
    sort=True,
    err_style='band',
    #legend='full',
)
ax.set_xlabel('')
ax.set_ylabel("Relative Reconstruction Error")
ax.legend(title="Algorithm", loc="upper left", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])

ax = fig.add_subplot(312)
sns.lineplot(
    x="p",
    y="acc_score",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations_90_snp.query("n_components == 50"),# and alg == 'NmfHyperEstimator'"),
    estimator='mean',
    ci=95,
    n_boot=1000,
    markers=True,
    seed=None,
    sort=True,
    err_style='band',
    legend='full',
)
ax.set_xlabel('')
ax.set_ylabel("Accuracy Score")
ax.legend(title="Algorithm", loc="upper right", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])

ax = fig.add_subplot(313)
sns.lineplot(
    x="p",
    y="nmi_score",
    hue="alg",
    #size="n_components",
    style="alg",
    data=evaluations_90_snp.query("n_components == 50"),# and noise_level==0.1"),# and alg == 'NmfHyperEstimator'"),
    estimator='mean',
    ci=95,
    markers=True,
    n_boot=1000,
    seed=None,
    sort=True,
    err_style='band',
    legend='full',
)
ax.set_xlabel("Noise level")
ax.set_ylabel("Normalised Mutual Info Score")
ax.legend(title="Algorithm", loc="upper right", labels=['NMF (sklearn)','L2-NMF','Hypersurface'])
plt.title("Model performances with n_components=50")
plt.savefig("snp_scaled_90%")

# %%
(evaluations_90_snp.query("n_components == 50")# and ratio==0.5")
 .sort_values(["rre"]))#, "acc_score"]))
# Out:
#                   alg n_components kwargs noise_id  noise_level  ratio  \
# 0         ModifiedNMF           50     {}        0          NaN    NaN
# 3         ModifiedNMF           50     {}        0          NaN    NaN
# 2   NmfHyperEstimator           50     {}        0          NaN    NaN
# 6         ModifiedNMF           50     {}        0          NaN    NaN
# 8   NmfHyperEstimator           50     {}        0          NaN    NaN
# 1      NmfL2Estimator           50     {}        0          NaN    NaN
# 7      NmfL2Estimator           50     {}        0          NaN    NaN
# 4      NmfL2Estimator           50     {}        0          NaN    NaN
# 5   NmfHyperEstimator           50     {}        0          NaN    NaN
# 14  NmfHyperEstimator           50     {}        1          NaN    NaN
# 11  NmfHyperEstimator           50     {}        1          NaN    NaN
# 17  NmfHyperEstimator           50     {}        1          NaN    NaN
# 12        ModifiedNMF           50     {}        1          NaN    NaN
# 9         ModifiedNMF           50     {}        1          NaN    NaN
# 15        ModifiedNMF           50     {}        1          NaN    NaN
# 13     NmfL2Estimator           50     {}        1          NaN    NaN
# 10     NmfL2Estimator           50     {}        1          NaN    NaN
# 16     NmfL2Estimator           50     {}        1          NaN    NaN
# 23  NmfHyperEstimator           50     {}        2          NaN    NaN
# 20  NmfHyperEstimator           50     {}        2          NaN    NaN
# 26  NmfHyperEstimator           50     {}        2          NaN    NaN
# 21        ModifiedNMF           50     {}        2          NaN    NaN
# 18        ModifiedNMF           50     {}        2          NaN    NaN
# 24        ModifiedNMF           50     {}        2          NaN    NaN
# 22     NmfL2Estimator           50     {}        2          NaN    NaN
# 19     NmfL2Estimator           50     {}        2          NaN    NaN
# 25     NmfL2Estimator           50     {}        2          NaN    NaN
# 32  NmfHyperEstimator           50     {}        3          NaN    NaN
# 29  NmfHyperEstimator           50     {}        3          NaN    NaN
# 35  NmfHyperEstimator           50     {}        3          NaN    NaN
# 30        ModifiedNMF           50     {}        3          NaN    NaN
# 27        ModifiedNMF           50     {}        3          NaN    NaN
# 33        ModifiedNMF           50     {}        3          NaN    NaN
# 31     NmfL2Estimator           50     {}        3          NaN    NaN
# 28     NmfL2Estimator           50     {}        3          NaN    NaN
# 34     NmfL2Estimator           50     {}        3          NaN    NaN
# 41  NmfHyperEstimator           50     {}        4          NaN    NaN
# 38  NmfHyperEstimator           50     {}        4          NaN    NaN
# 44  NmfHyperEstimator           50     {}        4          NaN    NaN
# 39        ModifiedNMF           50     {}        4          NaN    NaN
# 36        ModifiedNMF           50     {}        4          NaN    NaN
# 42        ModifiedNMF           50     {}        4          NaN    NaN
# 40     NmfL2Estimator           50     {}        4          NaN    NaN
# 37     NmfL2Estimator           50     {}        4          NaN    NaN
# 43     NmfL2Estimator           50     {}        4          NaN    NaN
#
#    trial_id       rre  acc_score  nmi_score    p    r
# 0         0  0.111690    0.63750   0.799725  0.0  0.5
# 3         1  0.113261    0.65625   0.808724  0.0  0.5
# 2         0  0.113488    0.80625   0.895614  0.0  0.5
# 6         2  0.113603    0.65625   0.789539  0.0  0.5
# 8         2  0.128044    0.79375   0.888017  0.0  0.5
# 1         0  0.132284    0.76875   0.878129  0.0  0.5
# 7         2  0.133660    0.74375   0.856337  0.0  0.5
# 4         1  0.134484    0.69375   0.839851  0.0  0.5
# 5         1  0.141238    0.75625   0.874675  0.0  0.5
# 14        1  0.282035    0.62500   0.793642  0.1  0.5
# 11        0  0.285104    0.68750   0.809669  0.1  0.5
# 17        2  0.285163    0.69375   0.819633  0.1  0.5
# 12        1  0.286052    0.56875   0.763573  0.1  0.5
# 9         0  0.287619    0.61875   0.790402  0.1  0.5
# 15        2  0.288840    0.63750   0.806812  0.1  0.5
# 13        1  0.301006    0.60625   0.781118  0.1  0.5
# 10        0  0.302243    0.61250   0.783053  0.1  0.5
# 16        2  0.304068    0.63125   0.785067  0.1  0.5
# 23        1  0.355688    0.57500   0.746728  0.2  0.5
# 20        0  0.357380    0.54375   0.722721  0.2  0.5
# 26        2  0.357705    0.57500   0.745115  0.2  0.5
# 21        1  0.363708    0.51875   0.688166  0.2  0.5
# 18        0  0.364729    0.52500   0.720889  0.2  0.5
# 24        2  0.366947    0.54375   0.721775  0.2  0.5
# 22        1  0.378495    0.44375   0.672835  0.2  0.5
# 19        0  0.378713    0.43750   0.643105  0.2  0.5
# 25        2  0.380875    0.45625   0.659665  0.2  0.5
# 32        1  0.401095    0.45625   0.668111  0.3  0.5
# 29        0  0.402923    0.43125   0.640140  0.3  0.5
# 35        2  0.403923    0.46250   0.678875  0.3  0.5
# 30        1  0.413336    0.43750   0.634903  0.3  0.5
# 27        0  0.414479    0.48750   0.679249  0.3  0.5
# 33        2  0.415434    0.49375   0.699166  0.3  0.5
# 31        1  0.426087    0.34375   0.611344  0.3  0.5
# 28        0  0.426643    0.40000   0.625183  0.3  0.5
# 34        2  0.428339    0.37500   0.586739  0.3  0.5
# 41        1  0.435497    0.40625   0.629633  0.4  0.5
# 38        0  0.437094    0.41875   0.624471  0.4  0.5
# 44        2  0.437456    0.43750   0.655288  0.4  0.5
# 39        1  0.449147    0.40625   0.611770  0.4  0.5
# 36        0  0.450519    0.38125   0.612959  0.4  0.5
# 42        2  0.451410    0.43750   0.624161  0.4  0.5
# 40        1  0.460948    0.36250   0.589755  0.4  0.5
# 37        0  0.463053    0.35000   0.567680  0.4  0.5
# 43        2  0.463625    0.38125   0.598786  0.4  0.5
